# %%
import os

import matplotlib.pyplot as plt
import pandas as pd
import requests
import seaborn as sns

# %%
imgs_path = "/".join(os.getcwd().split("/")[:-1]) + "/docs/img/"
imgs_path
# Out:
# '/home/samoed/Desktop/ESGanalysis/docs/img/'

# %% [markdown]
# # Reviews count

# %%
params = {
    "start_date": "1970-01-01",
    "end_date": "2023-05-10",
    "source_sites": ["banki.ru", "sravni.ru", "vk.com/comments"],
    "aggregate_by": "month",
}

response = requests.get("https://ai-service.ethics-hse.ru/views/reviews_count", params=params)
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '{"items":[{"date":"2005-03-01","source_site":"banki.ru","source_type":"reviews","count":10},{"date":"2005-04-01","source_site":"banki.ru","source_type":"reviews","count":99},{"date":"2005-05-01","source_site":"banki.ru","source_type":"reviews","count":128},{"date":"2005-06-01","source_site":"banki.ru","source_type":"reviews","count":138},{"date":"2005-07-01","source_site":"banki.ru","source_type":"reviews","count":143},{"date":"2005-08-01","source_site":"banki.ru","source_type":"reviews","count":149},{"date":"2005-09-01","source_site":"banki.ru","source_type":"reviews","count":152},{"date":"2005-10-01","source_site":"banki.ru","source_type":"reviews","count":222},{"date":"2005-11-01","source_site":"banki.ru","source_type":"reviews","count":162},{"date":"2005-12-01","source_site":"banki.ru","source_type":"reviews","count":162},{"date":"2006-01-01","source_site":"banki.ru","source_type":"reviews","count":146},{"date":"2006-02-01","source_site":"banki.ru","source_type":"reviews","count":132},{"date":"2006-03-01","source_site":"banki.ru","source_type":"reviews","count":195},{"date":"2006-04-01","source_site":"banki.ru","source_type":"reviews","count":161},{"date":"2006-05-01","source_site":"banki.ru","source_type":"reviews","count":157},{"date":"2006-06-01","source_site":"banki.ru","source_type":"reviews","count":124},{"date":"2006-07-01","source_site":"banki.ru","source_type":"reviews","count":116},{"date":"2006-08-01","source_site":"banki.ru","source_type":"reviews","count":118},{"date":"2006-09-01","source_site":"banki.ru","source_type":"reviews","count":112},{"date":"2006-10-01","source_site":"banki.ru","source_type":"reviews","count":106},{"date":"2006-11-01","source_site":"banki.ru","source_type":"reviews","count":115},{"date":"2006-12-01","source_site":"banki.ru","source_type":"reviews","count":141},{"date":"2007-01-01","source_site":"banki.ru","source_type":"reviews","count":135},{"date":"2007-02-01","source_site":"banki.ru","source_type":"reviews","count":118},{"date":"2007-03-01","source_site":"banki.ru","source_type":"reviews","count":158},{"date":"2007-04-01","source_site":"banki.ru","source_type":"reviews","count":187},{"date":"2007-05-01","source_site":"banki.ru","source_type":"reviews","count":160},{"date":"2007-06-01","source_site":"banki.ru","source_type":"reviews","count":168},{"date":"2007-07-01","source_site":"banki.ru","source_type":"reviews","count":209},{"date":"2007-08-01","source_site":"banki.ru","source_type":"reviews","count":238},{"date":"2007-09-01","source_site":"banki.ru","source_type":"reviews","count":183},{"date":"2007-10-01","source_site":"banki.ru","source_type":"reviews","count":204},{"date":"2007-11-01","source_site":"banki.ru","source_type":"reviews","count":212},{"date":"2007-12-01","source_site":"banki.ru","source_type":"reviews","count":245},{"date":"2008-01-01","source_site":"banki.ru","source_type":"reviews","count":199},{"date":"2008-02-01","source_site":"banki.ru","source_type":"reviews","count":232},{"date":"2008-03-01","source_site":"banki.ru","source_type":"reviews","count":235},{"date":"2008-04-01","source_site":"banki.ru","source_type":"reviews","count":232},{"date":"2008-05-01","source_site":"banki.ru","source_type":"reviews","count":219},{"date":"2008-06-01","source_site":"banki.ru","source_type":"reviews","count":232},{"date":"2008-07-01","source_site":"banki.ru","source_type":"reviews","count":264},{"date":"2008-08-01","source_site":"banki.ru","source_type":"reviews","count":242},{"date":"2008-09-01","source_site":"banki.ru","source_type":"reviews","count":265},{"date":"2008-10-01","source_site":"banki.ru","source_type":"reviews","count":412},{"date":"2008-11-01","source_site":"banki.ru","source_type":"reviews","count":306},{"date":"2008-12-01","source_site":"banki.ru","source_type":"reviews","count":322},{"date":"2009-01-01","source_site":"banki.ru","source_type":"reviews","count":282},{"date":"2009-02-01","source_site":"banki.ru","source_type":"reviews","count":261},{"date" ...

# %%
df = pd.DataFrame(response.json()["items"])
df.head()
# Out:
#          date source_site source_type  count
# 0  2005-03-01    banki.ru     reviews     10
# 1  2005-04-01    banki.ru     reviews     99
# 2  2005-05-01    banki.ru     reviews    128
# 3  2005-06-01    banki.ru     reviews    138
# 4  2005-07-01    banki.ru     reviews    143

# %%
arr = []
for i in range(2005, 2024):
    arr.append(i)
    arr.extend([None for _ in range(11)])
arr = arr[: df["date"].nunique()]

# %%
sns.lineplot(data=df, x="date", y="count", hue="source_site")
plt.xticks(range(df["date"].nunique()), arr, rotation=90)
plt.title("Количество собраных отзывов")
plt.savefig(imgs_path + "reviews_count")

# %% [markdown]
# # Ethics

# %%
params = {
    "bank_ids": [1000, 1, 1481],
    "model_names": "ethics_model_sentiment_test",
    "source_type": "reviews",
    "aggregate_by_year": True,
    "index_type": "index_safe",
}
data = requests.get("https://ai-service.ethics-hse.ru/views/aggregate_text_result", params=params)
data
# Out:
# <Response [200]>

# %%
df = pd.DataFrame(data.json()["items"])
df.head()
# Out:
#    year  quarter        date          bank_name  bank_id  \
# 0  2005        1  2005-03-01  АО ЮниКредит Банк        1
# 1  2005        1  2005-03-01     Банк ВТБ (ПАО)     1000
# 2  2005        1  2005-03-01       ПАО Сбербанк     1481
# 3  2005        2  2005-06-01  АО ЮниКредит Банк        1
# 4  2005        2  2005-06-01     Банк ВТБ (ПАО)     1000
#
#                     model_name source_type     index  index_10_percentile  \
# 0  ethics_model_sentiment_test     reviews  1.582339             0.000000
# 1  ethics_model_sentiment_test     reviews  0.000000             0.000000
# 2  ethics_model_sentiment_test     reviews  0.001620             0.000000
# 3  ethics_model_sentiment_test     reviews  0.072500            -0.417661
# 4  ethics_model_sentiment_test     reviews  0.166332            -0.417661
#
#    index_90_percentile
# 0             0.452731
# 1             0.452731
# 2             0.452731
# 3             0.452731
# 4             0.452731

# %%
plt.figure(figsize=(10, 5), dpi=200)
sns.lineplot(data=df, x="year", y="index", hue="bank_name", errorbar=None)
plt.xticks(range(2005, 2024))
plt.title(f"Индекс этичности")
plt.xlabel(None)
plt.ylabel(None)
plt.ylim([-1, 1])
plt.savefig(imgs_path + f"ethics_plot_{params['index_type']}", transparent=True)
