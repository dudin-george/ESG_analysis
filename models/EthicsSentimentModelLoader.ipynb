# %% [markdown]
# # Загружаем предложения

# %%
sentences = [
    "В общем, кто ещё думает, советую, хороший банк без офисов и прочей головной боли.",
    "Но уже через 40 минут дзилинь и новая ссылка в ответ на мое обращение, ещё раз ввела все данные и успешно активировала карту Pay, так что теперь и я с картой этого крутого банка.",
    "Форменное безобразие и полное наплевательское отношение к работе.",
    "Я, как добросовестный плательщик, без единого дня просрочки вносила платеж на протяжении нескольких лет, а вы, вместо того, что бы продемонстрировать свой профессионализм - умудряетесь в очередной раз ударить в грязь лицом.",
    "Спасибо ей и Банку Абсолют за работу.",
    "Спасибо за такое чуткое отношение и еще и приятные бонусы.",
    "Милый сотрудник в офисе сказал, что скоро всё будет готово, и за ними можно будет подъехать.",
    "Считаю, что вклад под 8,4 % один из самых выгодных в городе.",
    "Честно говоря, чувствуешь себя так, как будто пришел к старым, добрым друзьям, которые тебе всегда рады.",
    'Но к сожалению в банке отказали и не приняли документы, на что сказали:"Мы не можем вам дать официальный отказ, но принять документы тоже не можем, так как нет внутреннего распоряжения, когда будет неизвестно".',
    "Твердая пятерка в оценке работы банка.",
    "Нет своевременного решение проблем,ни кто ничего не знает,постоянно переключают,все праходит на устном уровне,то что говорится,того нет в договоре.",
    "На что мне ответили, что это уже хамство и она дала официальный комментарий устно, письменно отвечать не будет и бросила трубку.",
    "И тишина... Никто не звонит, не пишет, ни смсит... В конце прошлой недели пыталась дозвониться менеджеру - оказывается, в 16.00 его рабочий день закончился.",
    "Одно для меня непонятно: все эти мои злоключения и испорченная, в итоге, кредитная история - следствие некомпетентности сотрудников или эффект от целенаправленных действий банка по честному отъему у бывшего клиента 600 рублей штрафа?",
    "Я считаю это обманом банком своих клиентов.2.",
    "Это надо себя совсем не уважать, чтобы оставаться ВИП-клиентом этого банка при таком отношении руководителя!",
    "Сотрудники торопятся, грубят, безразличны.",
    "Не советую обращаться: потеряете и время и деньги, и нервы!",
    "Я честно говоря малость опешил - все доллары отменного качества, я их покупаю строго только в двух банках - Абсолюте и еще одном уважаемом банке (не упоминаю имя, чтобы не подумали, что реклама).",
]

# %%
import torch

# using Cuda if possible
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")

# %%
import ModelSentiment

# %%
# m = ModelSentiment.ModelSentiment('model-sentiment', device)
m = ModelSentiment.ModelSentiment("model-categories", device)

# %%
m.class_names()
# Out:
# {0: 'LABEL_0', 1: 'LABEL_1', 2: 'LABEL_2', 3: 'LABEL_3', 4: 'LABEL_4'}

# %%
m(sentences)
# Out:
# array([[5.92169404e-01, 2.73844171e-02, 1.85822062e-02, 3.57764333e-01,
#         4.09955159e-03],
#        [7.37483129e-02, 4.28925939e-02, 2.76490673e-03, 8.77769351e-01,
#         2.82487110e-03],
#        [8.01799074e-02, 1.55884832e-01, 1.02329871e-03, 7.60673404e-01,
#         2.23855092e-03],
#        [1.27898604e-01, 1.20964609e-01, 8.31625052e-03, 7.30364501e-01,
#         1.24560799e-02],
#        [3.09749037e-01, 4.38697875e-01, 6.82035508e-03, 2.40266353e-01,
#         4.46641212e-03],
#        [1.69665143e-01, 3.96850079e-01, 5.79882413e-03, 4.24974650e-01,
#         2.71134544e-03],
#        [2.71706969e-01, 5.46380401e-01, 4.35985206e-03, 1.72663927e-01,
#         4.88889776e-03],
#        [5.06526306e-02, 7.53968535e-03, 8.47713292e-01, 6.61040470e-02,
#         2.79903505e-02],
#        [2.33638480e-01, 4.95077431e-01, 4.27972712e-03, 2.63985634e-01,
#         3.01877502e-03],
#        [7.75979236e-02, 2.25413293e-01, 6.05569978e-04, 6.94696426e-01,
# ...
